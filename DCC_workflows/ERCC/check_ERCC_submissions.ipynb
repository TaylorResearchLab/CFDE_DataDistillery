# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', None)
from collections import Counter
from glob import glob

# %%
# connect to CHLO
# GENCODE to CHLO

# %% [markdown]
# # Use case 1: Uploaded 3/16 to globus

# %%
'''
I’ve just uploaded a complete set of nodes and edges TSV files for our first 
proposed use case. Would someone be able to look at these files and let us know if 
everything looks fine?
 
For our use case we determined which genes overlap with the binding site coordinates of
specific RNA binding proteins. We are currently using ENSEMBL gene ids to represent these 
genes because we found the overlaps using GENCODE v43 gene annotations. We were previously 
planning to use HGNC ids but not all genes had an HGNC id available. When available, the HGNC id
belonging to a specific gene is listed in node_dbxrefs. Would you confirm this is fine?
'''

# %%
ERCC_path = '/Users/stearb/Desktop/DESKTOP_TRANSFER/DataDistilleryFiles/ERCC/'

# %%
nodes1 = pd.read_csv(ERCC_path+'useCase1/ERCC_UseCase1_nodes.tsv',sep='\t',header=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nodes1 = pd.read_csv(ERCC_path+'useCase1/ERCC_UseCase1_nodes.tsv',sep='\t',header=0)
#
# NameError: name 'ERCC_path' is not defined

# %%
nodes1[nodes1['node_id'].str.contains('/')]
# Out:
#                                                node_id node_label
# 1149048  http://purl.obolibrary.org/obo/UBERON_0001359        NaN  \
# 1149049  http://purl.obolibrary.org/obo/UBERON_0001969        NaN
# 1149050  http://purl.obolibrary.org/obo/UBERON_0001836        NaN
# 1149051  http://purl.obolibrary.org/obo/UBERON_0001977        NaN
# 1149052  http://purl.obolibrary.org/obo/UBERON_0001088        NaN
#
#          node_synonyms node_dbxrefs
# 1149048            NaN          NaN
# 1149049            NaN          NaN
# 1149050            NaN          NaN
# 1149051            NaN          NaN
# 1149052            NaN          NaN

# %%
sab_splits = [i[0] for i in nodes1['node_id'].str.split(' ')]
Counter(sab_splits)

nodes1['sab'] = sab_splits
nodes1.head()

# %%
nodes1['sab'] = sab_splits
nodes1.head()
# Out:
#             node_id node_label  node_synonyms node_dbxrefs        sab
# 0  UNIPROTKB Q8N302        NaN            NaN          NaN  UNIPROTKB
# 1  UNIPROTKB P35269        NaN            NaN          NaN  UNIPROTKB
# 2  UNIPROTKB P14866        NaN            NaN          NaN  UNIPROTKB
# 3  UNIPROTKB Q9NUL3        NaN            NaN          NaN  UNIPROTKB
# 4  UNIPROTKB Q9H0D6        NaN            NaN          NaN  UNIPROTKB

# %%
nodes1[nodes1['sab']=='ENCODE_RBS_150_NO_OVERLAP']
# Out:
#                                                                    node_id
# 150         ENCODE_RBS_150_NO_OVERLAP chr1:12293606-12293614_plus_b38_FXR1  \
# 151         ENCODE_RBS_150_NO_OVERLAP chr1:12318124-12318156_plus_b38_FXR1
# 152         ENCODE_RBS_150_NO_OVERLAP chr1:12327804-12327855_plus_b38_FXR1
# 153         ENCODE_RBS_150_NO_OVERLAP chr1:15929840-15929851_plus_b38_FXR1
# 154         ENCODE_RBS_150_NO_OVERLAP chr1:15929909-15929912_plus_b38_FXR1
# ...                                                                    ...
# 458124     ENCODE_RBS_150_NO_OVERLAP chrX:70344076-70344164_plus_b38_CPSF6
# 458125    ENCODE_RBS_150_NO_OVERLAP chrX:77652194-77652196_minus_b38_CPSF6
# 458126  ENCODE_RBS_150_NO_OVERLAP chrX:123620548-123620627_minus_b38_CPSF6
# 458127   ENCODE_RBS_150_NO_OVERLAP chrX:124091782-124091795_plus_b38_CPSF6
# 458128   ENCODE_RBS_150_NO_OVERLAP chrX:124093405-124093466_plus_b38_CPSF6
#
#                                       node_label  node_synonyms node_dbxrefs
# 150         chr1:12293606-12293614_plus_b38_FXR1            NaN          NaN  \
# 151         chr1:12318124-12318156_plus_b38_FXR1            NaN          NaN
# 152         chr1:12327804-12327855_plus_b38_FXR1            NaN          NaN
# 153         chr1:15929840-15929851_plus_b38_FXR1            NaN          NaN
# 154         chr1:15929909-15929912_plus_b38_FXR1            NaN          NaN
# ...                                          ...            ...          ...
# 458124     chrX:70344076-70344164_plus_b38_CPSF6            NaN          NaN
# 458125    chrX:77652194-77652196_minus_b38_CPSF6            NaN          NaN
# 458126  chrX:123620548-123620627_minus_b38_CPSF6            NaN          NaN
# 458127   chrX:124091782-124091795_plus_b38_CPSF6            NaN          NaN
# 458128   chrX:124093405-124093466_plus_b38_CPSF6            NaN          NaN
#
#                               sab
# 150     ENCODE_RBS_150_NO_OVERLAP
# 151     ENCODE_RBS_150_NO_OVERLAP
# 152     ENCODE_RBS_150_NO_OVERLAP
# 153     ENCODE_RBS_150_NO_OVERLAP
# 154     ENCODE_RBS_150_NO_OVERLAP
# ...                           ...
# 458124  ENCODE_RBS_150_NO_OVERLAP
# 458125  ENCODE_RBS_150_NO_OVERLAP
# 458126  ENCODE_RBS_150_NO_OVERLAP
# 458127  ENCODE_RBS_150_NO_OVERLAP
# 458128  ENCODE_RBS_150_NO_OVERLAP
#
# [457979 rows x 5 columns]

# %% [markdown]
# ## Edges from use case 1

# %%
edges1 = pd.read_csv(ERCC_path+'useCase1/ERCC_UseCase1_edges.tsv',sep='\t',header=0)

# %%
edges1 = edges1.rename(columns={'subject_id':'subject',
                               'relationship':'predicate',
                               'object_id':'object'})

# %% [markdown]
# # 5/2 email: These are “ERCC_UseCase2a_nodes.tsv.gz”, “ERCC_UseCase2a_edges.tsv.gz”, and “ERCC_UseCase2b.tar.gz”. The use case 2a files contain information for eQTLs and the use case 2b zip contains information for cCREs. Within the tar.gz archive there are 37 files. The file named “ERCC_UseCase2b_gene_tissue_nodes.tsv” should be ingested first. The others do not need to be ingested in a specific order.
#
# ### I also noticed that there were some nodes and edges missing from our prior submission. These are contained within the files “ERCC_UseCase1_missing_nodes.tsv.gz” and “ERCC_UseCase1_missing_edges.tsv.gz”. These should complete the exRNA portion of our submission.

# %% [markdown]
# # First Combine the missing nodes and missing edges from use case 1 with the main edges and nodes files from use case 1

# %%
usecase1_missing_nodes = pd.read_csv(ERCC_path+
                                     'useCase1_missing_nodes_edges/ERCC_UseCase1_missing_nodes.tsv',sep='\t')

# %%
def fill_missing_cols(df):
    
    if 'node_id' not in df.columns:
        raise ValueError
        
    all_cols = set([ 'node_label', 'node_synonyms', 'node_dbxrefs',
            'node_definition','node_namespace','value','lowerbound','upperbound','unit'])
   
    missing_cols = list(all_cols - set(df.columns))
    nan_cols_df = pd.DataFrame(np.full([len(df), len(missing_cols)], np.nan),columns=missing_cols)
    nan_cols_df.index = df.index
    return pd.concat([df,nan_cols_df],axis=1)

# %% [markdown]
# # remove -,.,: ?
# # is ENSEMBL GENE_ID ok or should it be ENCODE GENE_ID?

# %%
#nan_cols_nodes1 = pd.DataFrame(np.full([len(nodes1), len(missing_cols)], np.nan),columns=missing_cols)
#nan_cols_missing_nodes1 = pd.DataFrame(np.full([len(usecase1_missing_nodes), 
#                    len(usecase1_missing_nodes_missing_cols)], np.nan),columns=usecase1_missing_nodes_missing_cols)


nodes1_full = fill_missing_cols(nodes1)
usecase1_missing_nodes_full = fill_missing_cols(usecase1_missing_nodes)

# %% [markdown]
# ### Append (usecase1) `nodes` and `missing_nodes together`

# %%
# Reorder them both so the correct columns get concatenated on top of eachother
nodes_usecase1_final = pd.concat([
                                usecase1_missing_nodes_full[np.sort(usecase1_missing_nodes_full.columns)],
                                nodes1_full[np.sort(nodes1_full.columns)]
                                ],axis=0)

# %%
nodes_usecase1_final.to_csv(ERCC_path+'USECASE_1_CLEANED/OWLNETS_node_metadata.txt',index=False,sep='\t')

# %% [markdown]
# ### Load in and append usecase1 missing edges to usecase1 edges file

# %%
usecase1_missing_edges = pd.read_csv(ERCC_path+
                                     'useCase1_missing_nodes_edges/ERCC_UseCase1_missing_edges.tsv',sep='\t')

usecase1_missing_edges = usecase1_missing_edges.rename(columns={'subject_id':'subject',
                                                               'relationship':'predicate',
                                                               'object_id':'object'})
usecase1_missing_edges
# Out:
#                                                                  subject
# 0     ENCODE_RBS_150_NO_OVERLAP chr1:234609218-234609225_minus_b38_ABCF1  \
# 1       ENCODE_RBS_150_NO_OVERLAP chr17:28722581-28722582_plus_b38_ABCF1
# 2      ENCODE_RBS_150_NO_OVERLAP chr17:82087399-82087437_minus_b38_ABCF1
# 3      ENCODE_RBS_150_NO_OVERLAP chr2:202276429-202276430_plus_b38_ABCF1
# 4            ENCODE_RBS_150_NO_OVERLAP chr5:648030-648037_plus_b38_ABCF1
# ...                                                                  ...
# 9275   ENCODE_RBS_150_NO_OVERLAP chr1:173866875-173866876_minus_b38_WDR3
# 9276     ENCODE_RBS_150_NO_OVERLAP chr17:19062036-19062043_plus_b38_WDR3
# 9277   ENCODE_RBS_150_NO_OVERLAP chr2:132257703-132257734_minus_b38_WDR3
# 9278    ENCODE_RBS_150_NO_OVERLAP chr20:26208702-26208706_minus_b38_WDR3
# 9279    ENCODE_RBS_150_NO_OVERLAP chr20:26209417-26209436_minus_b38_WDR3
#
#                                       predicate
# 0     http://purl.obolibrary.org/obo/RO_0002525  \
# 1     http://purl.obolibrary.org/obo/RO_0002525
# 2     http://purl.obolibrary.org/obo/RO_0002525
# 3     http://purl.obolibrary.org/obo/RO_0002525
# 4     http://purl.obolibrary.org/obo/RO_0002525
# ...                                         ...
# 9275  http://purl.obolibrary.org/obo/RO_0002131
# 9276  http://purl.obolibrary.org/obo/RO_0002131
# 9277  http://purl.obolibrary.org/obo/RO_0002131
# 9278  http://purl.obolibrary.org/obo/RO_0002131
# 9279  http://purl.obolibrary.org/obo/RO_0002131
#
#                                                         object
# 0     ENCODE_RBS_K562 chr1:234609152-234609225_minus_b38_ABCF1
# 1       ENCODE_RBS_K562 chr17:28722581-28722593_plus_b38_ABCF1
# 2      ENCODE_RBS_K562 chr17:82087399-82087437_minus_b38_ABCF1
# 3      ENCODE_RBS_K562 chr2:202276429-202276494_plus_b38_ABCF1
# 4            ENCODE_RBS_K562 chr5:647955-648037_plus_b38_ABCF1
# ...                                                        ...
# 9275                                ENSEMBL ENSG00000234741.10
# 9276                                 ENSEMBL ENSG00000265185.6
# 9277                                ENSEMBL ENSG00000163046.16
# 9278                                ENSEMBL ENSG00000227195.11
# 9279                                ENSEMBL ENSG00000227195.11
#
# [9280 rows x 3 columns]

# %%
# make sure col order is the same before append
edges_usecase1_final = pd.concat([edges1[['subject','predicate','object']],
                                    usecase1_missing_edges[['subject','predicate','object']]
                                ],axis=0)

edges_usecase1_final.to_csv(ERCC_path+'USECASE_1_CLEANED/OWLNETS_edgelist.txt',index=False,sep='\t')

# %%
# check why these edges didnt make it into the graph

# ENCODE_RBS_150_NO_OVERLAP	correlated_in	UBERON	22092	0	0.00
# ENCODE_RBS_150_NO_OVERLAP	not_correlated_in	UBERON	102	0	0.00


#nodes_usecase1 = pd.read_csv(ERCC_path+'USECASE_1_CLEANED/OWLNETS_node_metadata.txt',sep='\t')
edges_usecase1 = pd.read_csv(ERCC_path+'USECASE_1_CLEANED/OWLNETS_edgelist.txt',sep='\t')

# %%
edges_usecase1['object'] = [i.split('/')[-1] for i in edges_usecase1['object']]

# %%
edges_usecase1['object'] = [i.replace('_','/') for i if 'UBERON' in i else i in edges_usecase1['object']]
# Out:
#   Cell In[57], line 1
#     edges_usecase1['object'] = [i.replace('_','/') for i if 'UBERON' in i else i in edges_usecase1['object']]
#                                                        ^
# SyntaxError: cannot assign to conditional expression

# %%
#sab_splits = 
edges_usecase1['subject_sab'] = [i[0] for i in edges_usecase1['subject'].str.split(' ')]
edges_usecase1['object_sab'] = [i[0] for i in edges_usecase1['object'].str.split(' ')]

# %%
edges_usecase1[['subject_sab','predicate','object_sab']].drop_duplicates()
# Out:
#                        subject_sab                                  predicate
# 0                        UNIPROTKB  http://purl.obolibrary.org/obo/RO_0002436  \
# 20016                    UNIPROTKB  http://purl.obolibrary.org/obo/RO_0002436
# 20362                    UNIPROTKB  http://purl.obolibrary.org/obo/RO_0002436
# 690919   ENCODE_RBS_150_NO_OVERLAP  http://purl.obolibrary.org/obo/RO_0002525
# 695915   ENCODE_RBS_150_NO_OVERLAP  http://purl.obolibrary.org/obo/RO_0002525
# 697748   ENCODE_RBS_150_NO_OVERLAP  http://purl.obolibrary.org/obo/RO_0002525
# 1149071                  UNIPROTKB                               predicted_in
# 1149073                  UNIPROTKB                           not_predicted_in
# 1149129                  UNIPROTKB                               predicted_in
# 1149130                  UNIPROTKB                           not_predicted_in
# 1149184                  UNIPROTKB                               predicted_in
# 1149188                  UNIPROTKB                           not_predicted_in
# 1149304                  UNIPROTKB                           not_predicted_in
# 1149305                  UNIPROTKB                               predicted_in
# 1149382                  UNIPROTKB                               predicted_in
# 1149384                  UNIPROTKB                           not_predicted_in
# 1149455  ENCODE_RBS_150_NO_OVERLAP                              correlated_in
# 1149551  ENCODE_RBS_150_NO_OVERLAP                          not_correlated_in
# 1150785  ENCODE_RBS_150_NO_OVERLAP                              correlated_in
# 1150833  ENCODE_RBS_150_NO_OVERLAP                          not_correlated_in
# 1151937  ENCODE_RBS_150_NO_OVERLAP                              correlated_in
# 1165549  ENCODE_RBS_150_NO_OVERLAP                          not_correlated_in
# 1167520  ENCODE_RBS_150_NO_OVERLAP                              correlated_in
# 1167880  ENCODE_RBS_150_NO_OVERLAP                          not_correlated_in
# 1169730  ENCODE_RBS_150_NO_OVERLAP                              correlated_in
# 1170016  ENCODE_RBS_150_NO_OVERLAP                          not_correlated_in
# 1171649            ENCODE_RBS_K562  http://purl.obolibrary.org/obo/RO_0002131
# 1182002      ENCODE_RBS_HepG2_K562  http://purl.obolibrary.org/obo/RO_0002131
# 1193875           ENCODE_RBS_HepG2  http://purl.obolibrary.org/obo/RO_0002131
# 1926808  ENCODE_RBS_150_NO_OVERLAP  http://purl.obolibrary.org/obo/RO_0002131
#
#                                             object_sab
# 0                                ENCODE_RBS_HepG2_K562
# 20016                                  ENCODE_RBS_K562
# 20362                                 ENCODE_RBS_HepG2
# 690919                           ENCODE_RBS_HepG2_K562
# 695915                                ENCODE_RBS_HepG2
# 697748                                 ENCODE_RBS_K562
# 1149071  http://purl.obolibrary.org/obo/UBERON_0001359
# 1149073  http://purl.obolibrary.org/obo/UBERON_0001359
# 1149129  http://purl.obolibrary.org/obo/UBERON_0001969
# 1149130  http://purl.obolibrary.org/obo/UBERON_0001969
# 1149184  http://purl.obolibrary.org/obo/UBERON_0001836
# 1149188  http://purl.obolibrary.org/obo/UBERON_0001836
# 1149304  http://purl.obolibrary.org/obo/UBERON_0001977
# 1149305  http://purl.obolibrary.org/obo/UBERON_0001977
# 1149382  http://purl.obolibrary.org/obo/UBERON_0001088
# 1149384  http://purl.obolibrary.org/obo/UBERON_0001088
# 1149455  http://purl.obolibrary.org/obo/UBERON_0001359
# 1149551  http://purl.obolibrary.org/obo/UBERON_0001359
# 1150785  http://purl.obolibrary.org/obo/UBERON_0001969
# 1150833  http://purl.obolibrary.org/obo/UBERON_0001969
# 1151937  http://purl.obolibrary.org/obo/UBERON_0001836
# 1165549  http://purl.obolibrary.org/obo/UBERON_0001836
# 1167520  http://purl.obolibrary.org/obo/UBERON_0001977
# 1167880  http://purl.obolibrary.org/obo/UBERON_0001977
# 1169730  http://purl.obolibrary.org/obo/UBERON_0001088
# 1170016  http://purl.obolibrary.org/obo/UBERON_0001088
# 1171649                                        ENSEMBL
# 1182002                                        ENSEMBL
# 1193875                                        ENSEMBL
# 1926808                                        ENSEMBL

# %%
edges_usecase1[edges_usecase1['subject'].str.startswith('ENCODE_RBS_150_NO_OVERLAP') &\
              edges_usecase1['object'].str.startswith('ENCODE_RBS_HepG2_K562') ]['predicate'].unique()
# Out:
# array(['http://purl.obolibrary.org/obo/RO_0002525'], dtype=object)

# %% [markdown]
# # Look at use case 2a

# %%
# nodes
usecase2a_nodes = pd.read_csv(ERCC_path+
                                     'useCase2a/ERCC_UseCase2a_nodes.tsv',sep='\t')

# %%
nodes_usecase2a_final = fill_missing_cols(usecase2a_nodes)

# %%
sab_splits = [i[0] for i in nodes1['node_id'].str.split(' ')]
Counter(sab_splits)

nodes1['sab'] = sab_splits
nodes1.head()
# Out:
#             node_id node_label  node_synonyms node_dbxrefs        sab
# 0  UNIPROTKB Q8N302        NaN            NaN          NaN  UNIPROTKB
# 1  UNIPROTKB P35269        NaN            NaN          NaN  UNIPROTKB
# 2  UNIPROTKB P14866        NaN            NaN          NaN  UNIPROTKB
# 3  UNIPROTKB Q9NUL3        NaN            NaN          NaN  UNIPROTKB
# 4  UNIPROTKB Q9H0D6        NaN            NaN          NaN  UNIPROTKB

# %%
#Counter(nodes1['sab'])

'UNIPROTKB': 150,
'ENCODE_RBS_150_NO_OVERLAP': 457979,
'ENCODE_RBS_HepG2_K562': 446999,
'ENCODE_RBS_K562': 101464,
'ENCODE_RBS_HepG2': 142456
# Out:
#   Cell In[31], line 3
#     'UNIPROTKB': 150,
#     ^
# SyntaxError: illegal target for annotation

# %%
nodes_usecase2a_final.to_csv(ERCC_path+'USECASE_2a_CLEANED/OWLNETS_node_metadata.txt',index=False,sep='\t')

# %% [markdown]
# # check eqtl overlap and check tissue overlap and check HGNC HGNC:1234 format

# %%
# edges
usecase2a_edges = pd.read_csv(ERCC_path+
                                     'useCase2a/ERCC_UseCase2a_edges.tsv',sep='\t')

usecase2a_edges_final = usecase2a_edges.rename(columns={'subject_id':'subject',
                                                               'relationship':'predicate',
                                                               'object_id':'object'})

usecase2a_edges_final
# Out:
#                                                              subject
# 0                                  CLINGEN_ALLELE_REGISTRY CA7053557  \
# 1                      http://purl.obolibrary.org/obo/UBERON_0004648
# 2        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 3                                 CLINGEN_ALLELE_REGISTRY CA14743376
# 4                      http://purl.obolibrary.org/obo/UBERON_0001496
# ...                                                              ...
# 3024914                http://purl.obolibrary.org/obo/UBERON_0001496
# 3024915           GTEX_EQTL eQTL_chr15_89839388_C_T_b38_Artery_Aorta
# 3024916                           CLINGEN_ALLELE_REGISTRY CA13206740
# 3024917                http://purl.obolibrary.org/obo/UBERON_0001157
# 3024918      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
#
#                                           predicate
# 0        http://purl.obolibrary.org/obo/BFO_0000050  \
# 1        http://purl.obolibrary.org/obo/BFO_0000050
# 2         http://purl.obolibrary.org/obo/RO_0002213
# 3        http://purl.obolibrary.org/obo/BFO_0000050
# 4        http://purl.obolibrary.org/obo/BFO_0000050
# ...                                             ...
# 3024914  http://purl.obolibrary.org/obo/BFO_0000050
# 3024915   http://purl.obolibrary.org/obo/RO_0002212
# 3024916  http://purl.obolibrary.org/obo/BFO_0000050
# 3024917  http://purl.obolibrary.org/obo/BFO_0000050
# 3024918   http://purl.obolibrary.org/obo/RO_0002212
#
#                                                               object
# 0        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 1        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 2                                                    HGNC HGNC:15607
# 3                 GTEX_EQTL eQTL_chr19_16253903_G_A_b38_Artery_Aorta
# 4                 GTEX_EQTL eQTL_chr19_16253903_G_A_b38_Artery_Aorta
# ...                                                              ...
# 3024914           GTEX_EQTL eQTL_chr15_89839388_C_T_b38_Artery_Aorta
# 3024915                                                HGNC HGNC:571
# 3024916      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
# 3024917      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
# 3024918                                               HGNC HGNC:2926
#
# [3024919 rows x 3 columns]

# %%
usecase2a_edges_final.to_csv(ERCC_path+'USECASE_2a_CLEANED/OWLNETS_edgelist.txt',index=False,sep='\t')

# %%
usecase2a_edges_final = pd.read_csv(ERCC_path+'USECASE_2a_CLEANED/OWLNETS_edgelist.txt',sep='\t')
usecase2a_edges_final
# Out:
#                                                              subject
# 0                                  CLINGEN_ALLELE_REGISTRY CA7053557  \
# 1                      http://purl.obolibrary.org/obo/UBERON_0004648
# 2        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 3                                 CLINGEN_ALLELE_REGISTRY CA14743376
# 4                      http://purl.obolibrary.org/obo/UBERON_0001496
# ...                                                              ...
# 3024914                http://purl.obolibrary.org/obo/UBERON_0001496
# 3024915           GTEX_EQTL eQTL_chr15_89839388_C_T_b38_Artery_Aorta
# 3024916                           CLINGEN_ALLELE_REGISTRY CA13206740
# 3024917                http://purl.obolibrary.org/obo/UBERON_0001157
# 3024918      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
#
#                                           predicate
# 0        http://purl.obolibrary.org/obo/BFO_0000050  \
# 1        http://purl.obolibrary.org/obo/BFO_0000050
# 2         http://purl.obolibrary.org/obo/RO_0002213
# 3        http://purl.obolibrary.org/obo/BFO_0000050
# 4        http://purl.obolibrary.org/obo/BFO_0000050
# ...                                             ...
# 3024914  http://purl.obolibrary.org/obo/BFO_0000050
# 3024915   http://purl.obolibrary.org/obo/RO_0002212
# 3024916  http://purl.obolibrary.org/obo/BFO_0000050
# 3024917  http://purl.obolibrary.org/obo/BFO_0000050
# 3024918   http://purl.obolibrary.org/obo/RO_0002212
#
#                                                               object
# 0        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 1        GTEX_EQTL eQTL_chr13_111217690_T_C_b38_Esophagus_Muscularis
# 2                                                    HGNC HGNC:15607
# 3                 GTEX_EQTL eQTL_chr19_16253903_G_A_b38_Artery_Aorta
# 4                 GTEX_EQTL eQTL_chr19_16253903_G_A_b38_Artery_Aorta
# ...                                                              ...
# 3024914           GTEX_EQTL eQTL_chr15_89839388_C_T_b38_Artery_Aorta
# 3024915                                                HGNC HGNC:571
# 3024916      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
# 3024917      GTEX_EQTL eQTL_chr10_122560474_C_T_b38_Colon_Transverse
# 3024918                                               HGNC HGNC:2926
#
# [3024919 rows x 3 columns]

# %% [markdown]
# # Look at usecase 2b

# %%
# nodes

# load in and concatenate all sub-files for nodes and edges
# https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
usecase2b_node_paths = glob(ERCC_path+'useCase2b/ERCC_UseCase2b/*nodes*')
usecase2b_edge_paths = glob(ERCC_path+'useCase2b/ERCC_UseCase2b/*edges*')

def f(i):
    return pd.read_csv(i, sep='\t')

usecase2b_nodes = pd.concat(map(f, usecase2b_node_paths))  # ~3mil

# %%
sab_splits = [i[0] for i in usecase2b_nodes['node_id'].str.split(' ')]
usecase2b_nodes['sab'] = sab_splits
usecase2b_nodes.head()
Counter(sab_splits)
# Out:
# Counter({'SCREEN': 3258606,
#          'HGNC': 7998,
#          'http://www.ebi.ac.uk/efo/EFO_0001086': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002106': 1,
#          'http://purl.obolibrary.org/obo/CLO_0034837': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0006270': 1,
#          'http://purl.obolibrary.org/obo/CLO_0021752': 1,
#          'http://purl.obolibrary.org/obo/CLO_0021754': 1,
#          'http://purl.obolibrary.org/obo/CLO_0021511': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005725': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002779': 1,
#          'http://purl.obolibrary.org/obo/CL_0000236': 1,
#          'http://purl.obolibrary.org/obo/CL_0001054': 1,
#          'http://purl.obolibrary.org/obo/CL_0000624': 1,
#          'http://purl.obolibrary.org/obo/CL_0000897': 1,
#          'http://purl.obolibrary.org/obo/CL_0000895': 1,
#          'http://purl.obolibrary.org/obo/CL_0000625': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0001099': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007074': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002783': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005337': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005338': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002784': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005723': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007950': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0003042': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005904': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0003045': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007598': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002824': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005710': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0009318': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002793': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002791': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0001187': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0001196': 1,
#          'http://purl.obolibrary.org/obo/CLO_0007045': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002067': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005719': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005726': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0001203': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002234': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005724': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002798': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0001221': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005236': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0006711': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002074': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002847': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002713': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001211': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002323': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007610': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0002860': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0003072': 1,
#          'http://purl.obolibrary.org/obo/CL_0000084': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0005715': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002369': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001496': 1,
#          'http://purl.obolibrary.org/obo/CL_0000127': 1,
#          'http://purl.obolibrary.org/obo/CL_0002603': 1,
#          'http://purl.obolibrary.org/obo/CL_0002606': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001150': 1,
#          'http://purl.obolibrary.org/obo/CL_2000044': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000955': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0008367': 1,
#          'http://purl.obolibrary.org/obo/CL_0002328': 1,
#          'http://purl.obolibrary.org/obo/CL_0002548': 1,
#          'http://purl.obolibrary.org/obo/CL_0000746': 1,
#          'http://purl.obolibrary.org/obo/CL_0000706': 1,
#          'http://purl.obolibrary.org/obo/CL_0001059': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001621': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000016': 1,
#          'http://purl.obolibrary.org/obo/CL_0002252': 1,
#          'http://purl.obolibrary.org/obo/CL_0002306': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0004648': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0006920': 1,
#          'http://purl.obolibrary.org/obo/CL_0002553': 1,
#          'http://purl.obolibrary.org/obo/CL_0002555': 1,
#          'http://purl.obolibrary.org/obo/CL_0002557': 1,
#          'http://purl.obolibrary.org/obo/CL_0002547': 1,
#          'http://purl.obolibrary.org/obo/CL_0002558': 1,
#          'http://purl.obolibrary.org/obo/CL_1001608': 1,
#          'http://purl.obolibrary.org/obo/CL_1001606': 1,
#          'http://purl.obolibrary.org/obo/CL_2000045': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0011907': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002084': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002080': 1,
#          'http://purl.obolibrary.org/obo/CL_0000182': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007096': 1,
#          'http://www.ebi.ac.uk/efo/EFO_0007098': 1,
#          'http://purl.obolibrary.org/obo/CL_0000312': 1,
#          'http://purl.obolibrary.org/obo/CL_0002518': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002113': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000059': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002168': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0004264': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0008953': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002048': 1,
#          'http://purl.obolibrary.org/obo/CL_0002327': 1,
#          'http://purl.obolibrary.org/obo/CL_0000134': 1,
#          'http://purl.obolibrary.org/obo/BTO_0003953': 1,
#          'http://purl.obolibrary.org/obo/CL_0002372': 1,
#          'http://purl.obolibrary.org/obo/CL_0000623': 1,
#          'http://purl.obolibrary.org/obo/CL_0011020': 1,
#          'http://purl.obolibrary.org/obo/CL_0000047': 1,
#          'http://purl.obolibrary.org/obo/CL_0000062': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000992': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001264': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001987': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002367': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0008450': 1,
#          'http://purl.obolibrary.org/obo/CL_0002586': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0006631': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001114': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001159': 1,
#          'http://purl.obolibrary.org/obo/CL_0000188': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002108': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002240': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002106': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000945': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000473': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001515': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0002046': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0007610': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001323': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0001157': 1,
#          'http://purl.obolibrary.org/obo/CL_0000351': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0008952': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000995': 1,
#          'http://purl.obolibrary.org/obo/UBERON_0000996': 1})

# %%
usecase2b_nodes = fill_missing_cols(usecase2b_nodes)

# %%
# edges
usecase2b_edges = pd.concat(map(f,usecase2b_edge_paths))   # ~9mil

usecase2b_edges = usecase2b_edges.rename(columns={'subject_id':'subject',
                               'relationship':'predicate',
                               'object_id':'object'})

# %% [markdown]
# ### Replace `_` with `.` in SCREEN nodes and edges files

# %%
#usecase2b_nodes['node_id'] = [i.replace('_','.') if 'SCREEN' == i[:6]  else i for i in usecase2b_nodes['node_id']]

usecase2b_edges['subject'] = [i.replace('_','.') if 'SCREEN' == i[:6]  else i for i in usecase2b_edges['subject']]
usecase2b_edges['object'] = [i.replace('_','.') if 'SCREEN' == i[:6]  else i for i in usecase2b_edges['object']]

# %%
usecase2b_nodes.to_csv(ERCC_path+'USECASE_2B_CLEANED/OWLNETS_node_metadata.txt',index=False,sep='\t')

# %%
usecase2b_edges.to_csv(ERCC_path+'USECASE_2B_CLEANED/OWLNETS_edgelist.txt',index=False,sep='\t')

# %%
[i for i in usecase2b_nodes['node_id'] if '/' in i]
# Out:
# ['http://www.ebi.ac.uk/efo/EFO_0001086',
#  'http://www.ebi.ac.uk/efo/EFO_0002106',
#  'http://purl.obolibrary.org/obo/CLO_0034837',
#  'http://www.ebi.ac.uk/efo/EFO_0006270',
#  'http://purl.obolibrary.org/obo/CLO_0021752',
#  'http://purl.obolibrary.org/obo/CLO_0021754',
#  'http://purl.obolibrary.org/obo/CLO_0021511',
#  'http://www.ebi.ac.uk/efo/EFO_0005725',
#  'http://www.ebi.ac.uk/efo/EFO_0002779',
#  'http://purl.obolibrary.org/obo/CL_0000236',
#  'http://purl.obolibrary.org/obo/CL_0001054',
#  'http://purl.obolibrary.org/obo/CL_0000624',
#  'http://purl.obolibrary.org/obo/CL_0000897',
#  'http://purl.obolibrary.org/obo/CL_0000895',
#  'http://purl.obolibrary.org/obo/CL_0000625',
#  'http://www.ebi.ac.uk/efo/EFO_0001099',
#  'http://www.ebi.ac.uk/efo/EFO_0007074',
#  'http://www.ebi.ac.uk/efo/EFO_0002783',
#  'http://www.ebi.ac.uk/efo/EFO_0005337',
#  'http://www.ebi.ac.uk/efo/EFO_0005338',
#  'http://www.ebi.ac.uk/efo/EFO_0002784',
#  'http://www.ebi.ac.uk/efo/EFO_0005723',
#  'http://www.ebi.ac.uk/efo/EFO_0007950',
#  'http://www.ebi.ac.uk/efo/EFO_0003042',
#  'http://www.ebi.ac.uk/efo/EFO_0005904',
#  'http://www.ebi.ac.uk/efo/EFO_0003045',
#  'http://www.ebi.ac.uk/efo/EFO_0007598',
#  'http://www.ebi.ac.uk/efo/EFO_0002824',
#  'http://www.ebi.ac.uk/efo/EFO_0005710',
#  'http://www.ebi.ac.uk/efo/EFO_0009318',
#  'http://www.ebi.ac.uk/efo/EFO_0002793',
#  'http://www.ebi.ac.uk/efo/EFO_0002791',
#  'http://www.ebi.ac.uk/efo/EFO_0001187',
#  'http://www.ebi.ac.uk/efo/EFO_0001196',
#  'http://purl.obolibrary.org/obo/CLO_0007045',
#  'http://www.ebi.ac.uk/efo/EFO_0002067',
#  'http://www.ebi.ac.uk/efo/EFO_0005719',
#  'http://www.ebi.ac.uk/efo/EFO_0005726',
#  'http://www.ebi.ac.uk/efo/EFO_0001203',
#  'http://www.ebi.ac.uk/efo/EFO_0002234',
#  'http://www.ebi.ac.uk/efo/EFO_0005724',
#  'http://www.ebi.ac.uk/efo/EFO_0002798',
#  'http://www.ebi.ac.uk/efo/EFO_0001221',
#  'http://www.ebi.ac.uk/efo/EFO_0005236',
#  'http://www.ebi.ac.uk/efo/EFO_0006711',
#  'http://www.ebi.ac.uk/efo/EFO_0002074',
#  'http://www.ebi.ac.uk/efo/EFO_0002847',
#  'http://www.ebi.ac.uk/efo/EFO_0002713',
#  'http://purl.obolibrary.org/obo/UBERON_0001211',
#  'http://www.ebi.ac.uk/efo/EFO_0002323',
#  'http://www.ebi.ac.uk/efo/EFO_0007610',
#  'http://www.ebi.ac.uk/efo/EFO_0002860',
#  'http://www.ebi.ac.uk/efo/EFO_0003072',
#  'http://purl.obolibrary.org/obo/CL_0000084',
#  'http://www.ebi.ac.uk/efo/EFO_0005715',
#  'http://purl.obolibrary.org/obo/UBERON_0002369',
#  'http://purl.obolibrary.org/obo/UBERON_0001496',
#  'http://purl.obolibrary.org/obo/CL_0000127',
#  'http://purl.obolibrary.org/obo/CL_0002603',
#  'http://purl.obolibrary.org/obo/CL_0002606',
#  'http://purl.obolibrary.org/obo/UBERON_0001150',
#  'http://purl.obolibrary.org/obo/CL_2000044',
#  'http://purl.obolibrary.org/obo/UBERON_0000955',
#  'http://purl.obolibrary.org/obo/UBERON_0008367',
#  'http://purl.obolibrary.org/obo/CL_0002328',
#  'http://purl.obolibrary.org/obo/CL_0002548',
#  'http://purl.obolibrary.org/obo/CL_0000746',
#  'http://purl.obolibrary.org/obo/CL_0000706',
#  'http://purl.obolibrary.org/obo/CL_0001059',
#  'http://purl.obolibrary.org/obo/UBERON_0001621',
#  'http://purl.obolibrary.org/obo/UBERON_0000016',
#  'http://purl.obolibrary.org/obo/CL_0002252',
#  'http://purl.obolibrary.org/obo/CL_0002306',
#  'http://purl.obolibrary.org/obo/UBERON_0004648',
#  'http://purl.obolibrary.org/obo/UBERON_0006920',
#  'http://purl.obolibrary.org/obo/CL_0002553',
#  'http://purl.obolibrary.org/obo/CL_0002555',
#  'http://purl.obolibrary.org/obo/CL_0002557',
#  'http://purl.obolibrary.org/obo/CL_0002547',
#  'http://purl.obolibrary.org/obo/CL_0002558',
#  'http://purl.obolibrary.org/obo/CL_1001608',
#  'http://purl.obolibrary.org/obo/CL_1001606',
#  'http://purl.obolibrary.org/obo/CL_2000045',
#  'http://purl.obolibrary.org/obo/UBERON_0011907',
#  'http://purl.obolibrary.org/obo/UBERON_0002084',
#  'http://purl.obolibrary.org/obo/UBERON_0002080',
#  'http://purl.obolibrary.org/obo/CL_0000182',
#  'http://www.ebi.ac.uk/efo/EFO_0007096',
#  'http://www.ebi.ac.uk/efo/EFO_0007098',
#  'http://purl.obolibrary.org/obo/CL_0000312',
#  'http://purl.obolibrary.org/obo/CL_0002518',
#  'http://purl.obolibrary.org/obo/UBERON_0002113',
#  'http://purl.obolibrary.org/obo/UBERON_0000059',
#  'http://purl.obolibrary.org/obo/UBERON_0002168',
#  'http://purl.obolibrary.org/obo/UBERON_0004264',
#  'http://purl.obolibrary.org/obo/UBERON_0008953',
#  'http://purl.obolibrary.org/obo/UBERON_0002048',
#  'http://purl.obolibrary.org/obo/CL_0002327',
#  'http://purl.obolibrary.org/obo/CL_0000134',
#  'http://purl.obolibrary.org/obo/BTO_0003953',
#  'http://purl.obolibrary.org/obo/CL_0002372',
#  'http://purl.obolibrary.org/obo/CL_0000623',
#  'http://purl.obolibrary.org/obo/CL_0011020',
#  'http://purl.obolibrary.org/obo/CL_0000047',
#  'http://purl.obolibrary.org/obo/CL_0000062',
#  'http://purl.obolibrary.org/obo/UBERON_0000992',
#  'http://purl.obolibrary.org/obo/UBERON_0001264',
#  'http://purl.obolibrary.org/obo/UBERON_0001987',
#  'http://purl.obolibrary.org/obo/UBERON_0002367',
#  'http://purl.obolibrary.org/obo/UBERON_0008450',
#  'http://purl.obolibrary.org/obo/CL_0002586',
#  'http://purl.obolibrary.org/obo/UBERON_0006631',
#  'http://purl.obolibrary.org/obo/UBERON_0001114',
#  'http://purl.obolibrary.org/obo/UBERON_0001159',
#  'http://purl.obolibrary.org/obo/CL_0000188',
#  'http://purl.obolibrary.org/obo/UBERON_0002108',
#  'http://purl.obolibrary.org/obo/UBERON_0002240',
#  'http://purl.obolibrary.org/obo/UBERON_0002106',
#  'http://purl.obolibrary.org/obo/UBERON_0000945',
#  'http://purl.obolibrary.org/obo/UBERON_0000473',
#  'http://purl.obolibrary.org/obo/UBERON_0001515',
#  'http://purl.obolibrary.org/obo/UBERON_0002046',
#  'http://purl.obolibrary.org/obo/UBERON_0007610',
#  'http://purl.obolibrary.org/obo/UBERON_0001323',
#  'http://purl.obolibrary.org/obo/UBERON_0001157',
#  'http://purl.obolibrary.org/obo/CL_0000351',
#  'http://purl.obolibrary.org/obo/UBERON_0008952',
#  'http://purl.obolibrary.org/obo/UBERON_0000995',
#  'http://purl.obolibrary.org/obo/UBERON_0000996']

# %%
usecase2b_nodes = pd.read_csv(ERCC_path+'USECASE_2B_CLEANED/OWLNETS_node_metadata.txt',sep='\t')
usecase2b_nodes
# Out:
# /var/folders/tr/2p30dfsx26d1b953s0ymg6c9b0_rc1/T/ipykernel_80452/1641059200.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   usecase2b_nodes = pd.read_csv(ERCC_path+'USECASE_2B_CLEANED/OWLNETS_node_metadata.txt',sep='\t')
#                                    node_id                    node_label
# 0                      SCREEN EH38E2865685                  EH38E2865685  \
# 1           SCREEN EH38E2865685_EFO0009318            EH38E2865685_HFFc6
# 2                      SCREEN EH38E2865686                  EH38E2865686
# 3           SCREEN EH38E2865686_EFO0001196           EH38E2865686_IMR-90
# 4                      SCREEN EH38E2865688                  EH38E2865688
# ...                                    ...                           ...
# 3266728  SCREEN EH38E2769434_UBERON0000059  EH38E2769434_large_intestine
# 3266729     SCREEN EH38E2769434_EFO0007096     EH38E2769434_iPS_DF_19.11
# 3266730     SCREEN EH38E2769434_EFO0005723          EH38E2769434_GM23248
# 3266731     SCREEN EH38E2769434_EFO0002074             EH38E2769434_PC-3
# 3266732      SCREEN EH38E2769434_CL0000127        EH38E2769434_astrocyte
#
#                              node_definition node_synonyms  node_namespace
# 0                                       cCRE           NaN             NaN  \
# 1        cCRE within specific biosample type           NaN             NaN
# 2                                       cCRE           NaN             NaN
# 3        cCRE within specific biosample type           NaN             NaN
# 4                                       cCRE           NaN             NaN
# ...                                      ...           ...             ...
# 3266728  cCRE within specific biosample type           NaN             NaN
# 3266729  cCRE within specific biosample type           NaN             NaN
# 3266730  cCRE within specific biosample type           NaN             NaN
# 3266731  cCRE within specific biosample type           NaN             NaN
# 3266732  cCRE within specific biosample type           NaN             NaN
#
#          node_dbxrefs  upperbound  lowerbound  unit  value
# 0                 NaN         NaN         NaN   NaN    NaN
# 1                 NaN         NaN         NaN   NaN    NaN
# 2                 NaN         NaN         NaN   NaN    NaN
# 3                 NaN         NaN         NaN   NaN    NaN
# 4                 NaN         NaN         NaN   NaN    NaN
# ...               ...         ...         ...   ...    ...
# 3266728           NaN         NaN         NaN   NaN    NaN
# 3266729           NaN         NaN         NaN   NaN    NaN
# 3266730           NaN         NaN         NaN   NaN    NaN
# 3266731           NaN         NaN         NaN   NaN    NaN
# 3266732           NaN         NaN         NaN   NaN    NaN
#
# [3266733 rows x 10 columns]

# %%
usecase2b_nodes[usecase2b_nodes['node_id'].str.contains('UBERON0000059')]
# Out:
#                                    node_id                    node_label
# 53       SCREEN EH38E2866116_UBERON0000059  EH38E2866116_large_intestine  \
# 69       SCREEN EH38E2866117_UBERON0000059  EH38E2866117_large_intestine
# 90       SCREEN EH38E2866143_UBERON0000059  EH38E2866143_large_intestine
# 135      SCREEN EH38E2866174_UBERON0000059  EH38E2866174_large_intestine
# 175      SCREEN EH38E2866175_UBERON0000059  EH38E2866175_large_intestine
# ...                                    ...                           ...
# 3266420  SCREEN EH38E2768352_UBERON0000059  EH38E2768352_large_intestine
# 3266499  SCREEN EH38E2768526_UBERON0000059  EH38E2768526_large_intestine
# 3266508  SCREEN EH38E2768529_UBERON0000059  EH38E2768529_large_intestine
# 3266623  SCREEN EH38E2769187_UBERON0000059  EH38E2769187_large_intestine
# 3266728  SCREEN EH38E2769434_UBERON0000059  EH38E2769434_large_intestine
#
#                              node_definition node_synonyms  node_namespace
# 53       cCRE within specific biosample type           NaN             NaN  \
# 69       cCRE within specific biosample type           NaN             NaN
# 90       cCRE within specific biosample type           NaN             NaN
# 135      cCRE within specific biosample type           NaN             NaN
# 175      cCRE within specific biosample type           NaN             NaN
# ...                                      ...           ...             ...
# 3266420  cCRE within specific biosample type           NaN             NaN
# 3266499  cCRE within specific biosample type           NaN             NaN
# 3266508  cCRE within specific biosample type           NaN             NaN
# 3266623  cCRE within specific biosample type           NaN             NaN
# 3266728  cCRE within specific biosample type           NaN             NaN
#
#          node_dbxrefs  upperbound  lowerbound  unit  value
# 53                NaN         NaN         NaN   NaN    NaN
# 69                NaN         NaN         NaN   NaN    NaN
# 90                NaN         NaN         NaN   NaN    NaN
# 135               NaN         NaN         NaN   NaN    NaN
# 175               NaN         NaN         NaN   NaN    NaN
# ...               ...         ...         ...   ...    ...
# 3266420           NaN         NaN         NaN   NaN    NaN
# 3266499           NaN         NaN         NaN   NaN    NaN
# 3266508           NaN         NaN         NaN   NaN    NaN
# 3266623           NaN         NaN         NaN   NaN    NaN
# 3266728           NaN         NaN         NaN   NaN    NaN
#
# [53892 rows x 10 columns]

# %%
usecase2b_edges = pd.read_csv(ERCC_path+'USECASE_2B_CLEANED/OWLNETS_edgelist.txt',sep='\t')
usecase2b_edges.head(30)
# Out:
#                                           subject
# 0                             SCREEN EH38E3846211  \
# 1            http://www.ebi.ac.uk/efo/EFO_0002106
# 2                  SCREEN EH38E3846211_EFO0002106
# 3                             SCREEN EH38E3846211
# 4       http://purl.obolibrary.org/obo/CL_1001608
# 5                   SCREEN EH38E3846211_CL1001608
# 6                             SCREEN EH38E3846212
# 7            http://www.ebi.ac.uk/efo/EFO_0002106
# 8                  SCREEN EH38E3846212_EFO0002106
# 9                             SCREEN EH38E3846212
# 10      http://purl.obolibrary.org/obo/CL_1001608
# 11                  SCREEN EH38E3846212_CL1001608
# 12                            SCREEN EH38E3846214
# 13           http://www.ebi.ac.uk/efo/EFO_0002106
# 14                 SCREEN EH38E3846214_EFO0002106
# 15                            SCREEN EH38E3846216
# 16           http://www.ebi.ac.uk/efo/EFO_0002106
# 17                 SCREEN EH38E3846216_EFO0002106
# 18                            SCREEN EH38E3846216
# 19      http://purl.obolibrary.org/obo/CL_1001608
# 20                  SCREEN EH38E3846216_CL1001608
# 21                            SCREEN EH38E3846217
# 22  http://purl.obolibrary.org/obo/UBERON_0001264
# 23              SCREEN EH38E3846217_UBERON0001264
# 24                            SCREEN EH38E3846217
# 25           http://www.ebi.ac.uk/efo/EFO_0003045
# 26                 SCREEN EH38E3846217_EFO0003045
# 27                            SCREEN EH38E3846217
# 28      http://purl.obolibrary.org/obo/CL_0002548
# 29                  SCREEN EH38E3846217_CL0002548
#
#                                      predicate
# 0   http://purl.obolibrary.org/obo/BFO_0000050  \
# 1   http://purl.obolibrary.org/obo/BFO_0000050
# 2    http://purl.obolibrary.org/obo/RO_0002211
# 3   http://purl.obolibrary.org/obo/BFO_0000050
# 4   http://purl.obolibrary.org/obo/BFO_0000050
# 5    http://purl.obolibrary.org/obo/RO_0002211
# 6   http://purl.obolibrary.org/obo/BFO_0000050
# 7   http://purl.obolibrary.org/obo/BFO_0000050
# 8    http://purl.obolibrary.org/obo/RO_0002211
# 9   http://purl.obolibrary.org/obo/BFO_0000050
# 10  http://purl.obolibrary.org/obo/BFO_0000050
# 11   http://purl.obolibrary.org/obo/RO_0002211
# 12  http://purl.obolibrary.org/obo/BFO_0000050
# 13  http://purl.obolibrary.org/obo/BFO_0000050
# 14   http://purl.obolibrary.org/obo/RO_0002211
# 15  http://purl.obolibrary.org/obo/BFO_0000050
# 16  http://purl.obolibrary.org/obo/BFO_0000050
# 17   http://purl.obolibrary.org/obo/RO_0002211
# 18  http://purl.obolibrary.org/obo/BFO_0000050
# 19  http://purl.obolibrary.org/obo/BFO_0000050
# 20   http://purl.obolibrary.org/obo/RO_0002211
# 21  http://purl.obolibrary.org/obo/BFO_0000050
# 22  http://purl.obolibrary.org/obo/BFO_0000050
# 23   http://purl.obolibrary.org/obo/RO_0002211
# 24  http://purl.obolibrary.org/obo/BFO_0000050
# 25  http://purl.obolibrary.org/obo/BFO_0000050
# 26   http://purl.obolibrary.org/obo/RO_0002211
# 27  http://purl.obolibrary.org/obo/BFO_0000050
# 28  http://purl.obolibrary.org/obo/BFO_0000050
# 29   http://purl.obolibrary.org/obo/RO_0002211
#
#                                object
# 0      SCREEN EH38E3846211_EFO0002106
# 1      SCREEN EH38E3846211_EFO0002106
# 2                      HGNC HGNC:4221
# 3       SCREEN EH38E3846211_CL1001608
# 4       SCREEN EH38E3846211_CL1001608
# 5                      HGNC HGNC:4221
# 6      SCREEN EH38E3846212_EFO0002106
# 7      SCREEN EH38E3846212_EFO0002106
# 8                      HGNC HGNC:4221
# 9       SCREEN EH38E3846212_CL1001608
# 10      SCREEN EH38E3846212_CL1001608
# 11                     HGNC HGNC:4221
# 12     SCREEN EH38E3846214_EFO0002106
# 13     SCREEN EH38E3846214_EFO0002106
# 14                     HGNC HGNC:4221
# 15     SCREEN EH38E3846216_EFO0002106
# 16     SCREEN EH38E3846216_EFO0002106
# 17                     HGNC HGNC:4221
# 18      SCREEN EH38E3846216_CL1001608
# 19      SCREEN EH38E3846216_CL1001608
# 20                     HGNC HGNC:4221
# 21  SCREEN EH38E3846217_UBERON0001264
# 22  SCREEN EH38E3846217_UBERON0001264
# 23                     HGNC HGNC:4221
# 24     SCREEN EH38E3846217_EFO0003045
# 25     SCREEN EH38E3846217_EFO0003045
# 26                     HGNC HGNC:4221
# 27      SCREEN EH38E3846217_CL0002548
# 28      SCREEN EH38E3846217_CL0002548
# 29                     HGNC HGNC:4221

# %%
codes = pd.read_csv('/Users/stearb/Library/Application Support/Neo4j Desktop/Application/relate-data/dbmss/dbms-7fcafad9-8b40-4086-b2b1-143ea67fc66c/import/CODEs.csv')
codes
# Out:
# /var/folders/tr/2p30dfsx26d1b953s0ymg6c9b0_rc1/T/ipykernel_80452/454568973.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   codes = pd.read_csv('/Users/stearb/Library/Application Support/Neo4j Desktop/Application/relate-data/dbmss/dbms-7fcafad9-8b40-4086-b2b1-143ea67fc66c/import/CODEs.csv')
#                                   CodeID:ID          SAB
# 0                               MSH D015056          MSH  \
# 1                     SNOMEDCT_US 285407008  SNOMEDCT_US
# 2                             LNC LP17185-7          LNC
# 3                            CHV 0000000504          CHV
# 4                             GO GO:0004113           GO
# ...                                     ...          ...
# 19304313  SCREEN EH38E2769434.UBERON0000059       SCREEN
# 19304314     SCREEN EH38E2769434.EFO0007096       SCREEN
# 19304315     SCREEN EH38E2769434.EFO0005723       SCREEN
# 19304316     SCREEN EH38E2769434.EFO0002074       SCREEN
# 19304317      SCREEN EH38E2769434.CL0000127       SCREEN
#
#                                 CODE  value:float  lowerbound:float
# 0                            D015056          NaN               NaN  \
# 1                          285407008          NaN               NaN
# 2                          LP17185-7          NaN               NaN
# 3                         0000000504          NaN               NaN
# 4                         GO:0004113          NaN               NaN
# ...                              ...          ...               ...
# 19304313  EH38E2769434.UBERON0000059          NaN               NaN
# 19304314     EH38E2769434.EFO0007096          NaN               NaN
# 19304315     EH38E2769434.EFO0005723          NaN               NaN
# 19304316     EH38E2769434.EFO0002074          NaN               NaN
# 19304317      EH38E2769434.CL0000127          NaN               NaN
#
#           upperbound:float  unit
# 0                      NaN   NaN
# 1                      NaN   NaN
# 2                      NaN   NaN
# 3                      NaN   NaN
# 4                      NaN   NaN
# ...                    ...   ...
# 19304313               NaN   NaN
# 19304314               NaN   NaN
# 19304315               NaN   NaN
# 19304316               NaN   NaN
# 19304317               NaN   NaN
#
# [19304318 rows x 7 columns]

# %%
codes[codes['SAB']=='SCREEN']
# Out:
#                                   CodeID:ID     SAB
# 11088072                SCREEN EH38E2865685  SCREEN  \
# 11088073     SCREEN EH38E2865685_EFO0009318  SCREEN
# 11088074                SCREEN EH38E2865686  SCREEN
# 11088075     SCREEN EH38E2865686_EFO0001196  SCREEN
# 11088076                SCREEN EH38E2865688  SCREEN
# ...                                     ...     ...
# 19304313  SCREEN EH38E2769434.UBERON0000059  SCREEN
# 19304314     SCREEN EH38E2769434.EFO0007096  SCREEN
# 19304315     SCREEN EH38E2769434.EFO0005723  SCREEN
# 19304316     SCREEN EH38E2769434.EFO0002074  SCREEN
# 19304317      SCREEN EH38E2769434.CL0000127  SCREEN
#
#                                 CODE  value:float  lowerbound:float
# 11088072                EH38E2865685          NaN               NaN  \
# 11088073     EH38E2865685_EFO0009318          NaN               NaN
# 11088074                EH38E2865686          NaN               NaN
# 11088075     EH38E2865686_EFO0001196          NaN               NaN
# 11088076                EH38E2865688          NaN               NaN
# ...                              ...          ...               ...
# 19304313  EH38E2769434.UBERON0000059          NaN               NaN
# 19304314     EH38E2769434.EFO0007096          NaN               NaN
# 19304315     EH38E2769434.EFO0005723          NaN               NaN
# 19304316     EH38E2769434.EFO0002074          NaN               NaN
# 19304317      EH38E2769434.CL0000127          NaN               NaN
#
#           upperbound:float  unit
# 11088072               NaN   NaN
# 11088073               NaN   NaN
# 11088074               NaN   NaN
# 11088075               NaN   NaN
# 11088076               NaN   NaN
# ...                    ...   ...
# 19304313               NaN   NaN
# 19304314               NaN   NaN
# 19304315               NaN   NaN
# 19304316               NaN   NaN
# 19304317               NaN   NaN
#
# [6158101 rows x 7 columns]
